# %%
# import library and set up global parameters
import numpy as np
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

#data_path
data_path = "./data/day.csv"
seed = 1

# %%
def eleminate_upper_ouliers(data, columns, print_output = True):
    """
        Find outliers upper fence, value > Q3 + 1.5*IQR
        Input: Dataframe
        Output: Dataframe which eleminated outliers
    """
    df_quantile = data[columns].quantile([0.25, 0.75])
    Q1 = df_quantile[0.25]
    Q3 = df_quantile[0.75]
    IQR = Q3 - Q1
    upper_outlier = Q3+1.5*IQR
    
    ret_data = data[data[columns]<upper_outlier]
    
    # print some results
    if print_output:
        outliters = data[data[columns]>upper_outlier]
        print("Upper outliers of dataset:", upper_outlier)
        print("Num rows of outliers:", len(data) - len(ret_data))
        print("A look of boxplot after remove outliers")
        sns.boxplot(x = ret_data[columns])
        plt.plot()
    return ret_data, outliters

# %%
def plot_uni_numb(data, column, figsize=[20,10]):  
    plt.figure(figsize=figsize)

    # count number of category

    # firgue 1
    plt.subplot(1,3,1)
    sns.histplot(data = data[column])
    plt.title(("Histogram of" + column), fontsize=12)
    # firgue 2
    plt.subplot(1,3,2)
    sns.boxplot(data = data[column])
    plt.title("Box plot " + column, fontsize=12)
    # firgue 3
    plt.subplot(1,3,3)
    sns.boxplot(y = data[column], x= data['cnt'], palette = 'hls')
    plt.title("Box plot " + column, fontsize=12)


    plt.show()

# %%
def plot_bi_cate(data, column, figsize=[20,15], check_order = False):  
    plt.figure(figsize=figsize)

    if check_order:
        order = sorted(list(data[column].unique()))
    else:
        order = None

    plt.subplot(3,1,1)
    data[column].value_counts().plot.pie(autopct='%1.2f%%', shadow=True, startangle=90)
    plt.title(("Histogram of" + column), fontsize=12)

    plt.subplot(3,1,2)
    sns.countplot(x=data[column], order = order)
    plt.title(("Distribution of " + column), fontsize=12)

    plt.subplot(3,1,3)
    sns.barplot(x = data[column], y= data['cnt'], palette = 'hls', order = order)
    plt.title("Total rental bikes by " + column, fontsize=12)
    plt.show()

# %%
def linear_regression(X_train, y_train, X_test, y_test, print_summary = True, print_chart = True):
    """
        Linear regression model
    """
    X_train = sm.add_constant(X_train) # adding a constant
    model = sm.OLS(y_train, X_train).fit()
    X_test = sm.add_constant(X_test)
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)
    print("R2 Score of the training data:",r2_score(y_pred = y_pred_train, y_true = y_train))
    print("R2 Score of the testing data:",r2_score(y_pred = y_pred_test, y_true = y_test))
    if print_summary:
        print(model.summary())
    if print_chart:
        sns.regplot(y_test,y_pred_test)
    return model

# %%
def get_pvalues(model):
  pval = pd.DataFrame(data= model.pvalues, columns=['Pvalue'])
  pval['feature'] = pval.index
  pval.reset_index(drop=True, inplace=True)
  pval['Pvalue'] = [round(i,3) for i in pval['Pvalue']]
  pval = pval[['feature','Pvalue']].sort_values('Pvalue', ascending=False)
  return pval

# %%
def get_VIF(X_train):
  columns = X_train.columns
  # VIF DataFrame
  vif_data = pd.DataFrame()
  vif_data["feature"] = X_train.columns
  # calculating VIF for each feature
  vif_data["VIF"] = [variance_inflation_factor(X_train[columns].values, i) for i in range(len(columns))]
  vif_data = vif_data.sort_values('VIF', ascending=False)
  return vif_data

# %% [markdown]
# # DATA VISUALIZATION

# %% [markdown]
# ## 1. Loading data

# %% [markdown]
# **Dictionary**
# <ol>
#     <li>instant: record index</li>
#     <li>dteday : date</li>
#     <li>season : season (1:spring, 2:summer, 3:fall, 4:winter)</li>
#     <li>yr : year (0: 2018, 1:2019)</li>
#     <li>mnth : month ( 1 to 12)</li>
#     <li>holiday : weather day is a holiday or not</li>
#     <li>weekday : day of the week</li>
#     <li>workingday : if day is neither weekend nor holiday is 1, otherwise is 0.</li>
#     <li>
#         weathersit :
#         <ul>
#         <li>1: Clear, Few clouds, Partly cloudy, Partly cloudy - Clear</li>
#         <li>2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist - Mist</li>
#         <li>3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds - Light_Snow_Rain</li>
#         <li>4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog - Heavy_Rain</li>
#         </ul>
#     </li>
#     <li>temp : temperature in Celsius</li>
#     <li>atemp: feeling temperature in Celsius</li>
#     <li>hum: humidity</li>
#     <li>windspeed: wind speed</li>
#     <li>casual: count of casual users</li>
#     <li>registered: count of registered users</li>
#     <li>cnt: count of total rental bikes including both casual and registered</li>
# </ol>

# %%
dateparse = lambda x: datetime.datetime.strptime(x, '%d-%m-%Y')
df = pd.read_csv(data_path, parse_dates=['dteday'], date_parser=dateparse)
df.head()
# Out:
#    instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1 2018-01-01       1   0     1        0        6           0
# 1        2 2018-01-02       1   0     1        0        0           0
# 2        3 2018-01-03       1   0     1        0        1           1
# 3        4 2018-01-04       1   0     1        0        2           1
# 4        5 2018-01-05       1   0     1        0        3           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
# shape of data
df.shape
# Out:
# (730, 16)

# %%
# check non-null and types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    datetime64[ns]
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.4 KB

# %%
# decribe data
df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean   365.500000    2.498630    0.500000    6.526027    0.028767    2.997260
# std    210.877136    1.110184    0.500343    3.450215    0.167266    2.006161
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.250000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    365.500000    3.000000    0.500000    7.000000    0.000000    3.000000
# 75%    547.750000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    730.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     0.683562    1.394521   20.319259   23.726322   62.765175   12.763620
# std      0.465405    0.544807    7.506729    8.150308   14.237589    5.195841
# min      0.000000    1.000000    2.424346    3.953480    0.000000    1.500244
# 25%      0.000000    1.000000   13.811885   16.889713   52.000000    9.041650
# 50%      1.000000    1.000000   20.465826   24.368225   62.625000   12.125325
# 75%      1.000000    2.000000   26.880615   30.445775   72.989575   15.625589
# max      1.000000    3.000000   35.328347   42.044800   97.250000   34.000021
#
#             casual   registered          cnt
# count   730.000000   730.000000   730.000000
# mean    849.249315  3658.757534  4508.006849
# std     686.479875  1559.758728  1936.011647
# min       2.000000    20.000000    22.000000
# 25%     316.250000  2502.250000  3169.750000
# 50%     717.000000  3664.500000  4548.500000
# 75%    1096.500000  4783.250000  5966.000000
# max    3410.000000  6946.000000  8714.000000

# %% [markdown]
# **Remove**: from data under standing from dictionary, remove these columns, which are irrelavent

# %%
# instant: nothing to do with target
df.drop(['instant'], axis = 1, inplace = True)

# casual and registered: sum of them equal target
df.drop(['casual'], axis = 1, inplace = True)
df.drop(['registered'], axis = 1, inplace = True)

# %% [markdown]
# ## 2. Cleaning data

# %%
# Trailing Spaces filter
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %% [markdown]
# ### 2.1. Missing values

# %%
df.isnull().sum()
# Out:
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# cnt           0
# dtype: int64

# %% [markdown]
# **Conclusion**: No missing value, no need to impute data

# %% [markdown]
# ### 2.2. Dtypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   dteday      730 non-null    datetime64[ns]
#  1   season      730 non-null    int64
#  2   yr          730 non-null    int64
#  3   mnth        730 non-null    int64
#  4   holiday     730 non-null    int64
#  5   weekday     730 non-null    int64
#  6   workingday  730 non-null    int64
#  7   weathersit  730 non-null    int64
#  8   temp        730 non-null    float64
#  9   atemp       730 non-null    float64
#  10  hum         730 non-null    float64
#  11  windspeed   730 non-null    float64
#  12  cnt         730 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(8)
# memory usage: 74.3 KB

# %% [markdown]
# **Conclusion**: Dtypes good, no "object" type found. Can derive from dteday later

# %% [markdown]
# ### 2.3. Outliers

# %%
# Unique values in all columns
df.nunique()
# Out:
# dteday        730
# season          4
# yr              2
# mnth           12
# holiday         2
# weekday         7
# workingday      2
# weathersit      3
# temp          498
# atemp         689
# hum           594
# windspeed     649
# cnt           695
# dtype: int64

# %% [markdown]
# **Categorical Values**: season, yr, mnth, holiday, weekday, workingday, weathersit
#
# **Continuous Variables**: Others (not check dteday)

# %% [markdown]
# ##### temp

# %%
df["temp"].describe()
# Out:
# count    730.000000
# mean      20.319259
# std        7.506729
# min        2.424346
# 25%       13.811885
# 50%       20.465826
# 75%       26.880615
# max       35.328347
# Name: temp, dtype: float64

# %%
sns.boxplot(df["temp"])
# Out:
# <AxesSubplot:xlabel='temp'>

# %%
# outliers
df, outliers = eleminate_upper_ouliers(df, "temp")
# Out:
# Upper outliers of dataset: 46.483709
# Num rows of outliers: 0
# A look of boxplot after remove outliers

# %% [markdown]
# **Conclusion**: no outliers found in "temp"

# %% [markdown]
# ##### atemp

# %%
df["atemp"].describe()
# Out:
# count    730.000000
# mean      23.726322
# std        8.150308
# min        3.953480
# 25%       16.889713
# 50%       24.368225
# 75%       30.445775
# max       42.044800
# Name: atemp, dtype: float64

# %%
sns.boxplot(df["atemp"])
# Out:
# <AxesSubplot:xlabel='atemp'>

# %%
# outliers
df, outliers = eleminate_upper_ouliers(df, "atemp")
# Out:
# Upper outliers of dataset: 50.77986874999999
# Num rows of outliers: 0
# A look of boxplot after remove outliers

# %% [markdown]
# **Conclusion**: no outliers found in "temp"

# %% [markdown]
# ##### hum

# %%
df["hum"].describe()
# Out:
# count    730.000000
# mean      62.765175
# std       14.237589
# min        0.000000
# 25%       52.000000
# 50%       62.625000
# 75%       72.989575
# max       97.250000
# Name: hum, dtype: float64

# %%
sns.boxplot(df["hum"])
# Out:
# <AxesSubplot:xlabel='hum'>

# %%
# outliers
df, outliers = eleminate_upper_ouliers(df, "hum")
# Out:
# Upper outliers of dataset: 104.4739375
# Num rows of outliers: 0
# A look of boxplot after remove outliers

# %% [markdown]
# **Conclusion**: no outliers found in "hum"

# %% [markdown]
# ##### windspeed

# %%
df["windspeed"].describe()
# Out:
# count    730.000000
# mean      12.763620
# std        5.195841
# min        1.500244
# 25%        9.041650
# 50%       12.125325
# 75%       15.625589
# max       34.000021
# Name: windspeed, dtype: float64

# %%
sns.boxplot(df["windspeed"])
# Out:
# <AxesSubplot:xlabel='windspeed'>

# %%
# outliers
df, outliers = eleminate_upper_ouliers(df, "windspeed")
# Out:
# Upper outliers of dataset: 25.501498125
# Num rows of outliers: 13
# A look of boxplot after remove outliers

# %% [markdown]
# **Conclusion**: With the assumption that windspeed is normal distibution, delete 13 samples

# %% [markdown]
# ##### cnt

# %%
df["cnt"].describe()
# Out:
# count     717.000000
# mean     4531.154812
# std      1936.429965
# min        22.000000
# 25%      3214.000000
# 50%      4570.000000
# 75%      6031.000000
# max      8714.000000
# Name: cnt, dtype: float64

# %%
sns.boxplot(df["cnt"])
# Out:
# <AxesSubplot:xlabel='cnt'>

# %%
# outliers
df, outliers = eleminate_upper_ouliers(df, "cnt")
# Out:
# Upper outliers of dataset: 10256.5
# Num rows of outliers: 0
# A look of boxplot after remove outliers

# %% [markdown]
# **Conclusion**: No outliers found in cnt (target variable)

# %% [markdown]
# ### 2.4. Derive data
# Derive "dteday" to "day" and remove "dteday"
# day: categorical: 1-10: 0 (start-month), 11-20: 1 (mid-month), 21-30: 2 (end-month)
# <br>
# Derive "temp" to categorical: very_cold(<10), cold(10-15), normal(15-20), warm (20-25), hot(25-30), veryhot(>30)
# <br>
# Link: https://science.howstuffworks.com/nature/climate-weather/atmospheric/question651.htm#:~:text=Most%20people%20are%20comfortable%20with,and%20unable%20to%20cool%20down.
# Derive "hum" by the link: dry (<30), good(30-50), wet(>50)
# <br>
# Windspeed range: https://www.weather.gov/pqr/wind
# Derive "windspeed": calm(<1), light_air(1-3), light_breeze(4-7), gentle_breeze(8-12), moderate_breeze(13-18), fresh_freeze(19-24), strong_breeze(25-31) and near_gate(>=32)

# %%
part_month = lambda x: 0 if x<11 else 1 if x<21 else 2
df["day"] = [part_month(int(i.day)) for i in df['dteday']]
df.drop(['dteday'], axis=1, inplace=True)
df.head()
# Out:
#    season  yr  mnth  holiday  weekday  workingday  weathersit       temp  \
# 0       1   0     1        0        6           0           2  14.110847
# 1       1   0     1        0        0           0           2  14.902598
# 2       1   0     1        0        1           1           1   8.050924
# 3       1   0     1        0        2           1           1   8.200000
# 4       1   0     1        0        3           1           1   9.305237
#
#       atemp      hum  windspeed   cnt  day
# 0  18.18125  80.5833  10.749882   985    0
# 1  17.68695  69.6087  16.652113   801    0
# 2   9.47025  43.7273  16.636703  1349    0
# 3  10.60610  59.0435  10.739832  1562    0
# 4  11.46350  43.6957  12.522300  1600    0

# %%
temp_names = ["very_cold", "cold", "normal", "warm", "hot", "veryhot"]
df["temp_cat"] = df["temp"].apply(lambda x: temp_names[int(x-10)//5] if x>10 else temp_names[0])
df.head()
# Out:
#    season  yr  mnth  holiday  weekday  workingday  weathersit       temp  \
# 0       1   0     1        0        6           0           2  14.110847
# 1       1   0     1        0        0           0           2  14.902598
# 2       1   0     1        0        1           1           1   8.050924
# 3       1   0     1        0        2           1           1   8.200000
# 4       1   0     1        0        3           1           1   9.305237
#
#       atemp      hum  windspeed   cnt  day   temp_cat
# 0  18.18125  80.5833  10.749882   985    0  very_cold
# 1  17.68695  69.6087  16.652113   801    0  very_cold
# 2   9.47025  43.7273  16.636703  1349    0  very_cold
# 3  10.60610  59.0435  10.739832  1562    0  very_cold
# 4  11.46350  43.6957  12.522300  1600    0  very_cold

# %%
hum_names = ["dry", "good", "wet"]
df["hum_cat"] = df["hum"].apply(lambda x: hum_names[0] if x<30 else hum_names[2] if x>50 else hum_names[1])
df.head()
# Out:
#    season  yr  mnth  holiday  weekday  workingday  weathersit       temp  \
# 0       1   0     1        0        6           0           2  14.110847
# 1       1   0     1        0        0           0           2  14.902598
# 2       1   0     1        0        1           1           1   8.050924
# 3       1   0     1        0        2           1           1   8.200000
# 4       1   0     1        0        3           1           1   9.305237
#
#       atemp      hum  windspeed   cnt  day   temp_cat hum_cat
# 0  18.18125  80.5833  10.749882   985    0  very_cold     wet
# 1  17.68695  69.6087  16.652113   801    0  very_cold     wet
# 2   9.47025  43.7273  16.636703  1349    0  very_cold    good
# 3  10.60610  59.0435  10.739832  1562    0  very_cold     wet
# 4  11.46350  43.6957  12.522300  1600    0  very_cold    good

# %%
wind_names = ["calm", "light_air", "light_breeze", "gentle_breeze", "moderate_breeze", "fresh_freeze", "strong_breeze", "near_gate"]
def devide_speed(x):
    if x<1:
        wind_name = "calm"
    elif x<4:
        wind_name = "light_air"
    elif x<8:
        wind_name = "light_breeze"
    elif x<13:
        wind_name = "gentle_breeze"
    elif x<19:
        wind_name = "moderate_breeze"
    elif x<25:
        wind_name = "fresh_freeze"
    elif x<32:
        wind_name = "strong_breeze"
    else:
        wind_name = "near_gate"
    return wind_name
df["windspeed_cat"] = df["windspeed"].apply(lambda x:devide_speed(x))
df.head()
# Out:
#    season  yr  mnth  holiday  weekday  workingday  weathersit       temp  \
# 0       1   0     1        0        6           0           2  14.110847
# 1       1   0     1        0        0           0           2  14.902598
# 2       1   0     1        0        1           1           1   8.050924
# 3       1   0     1        0        2           1           1   8.200000
# 4       1   0     1        0        3           1           1   9.305237
#
#       atemp      hum  windspeed   cnt  day   temp_cat hum_cat    windspeed_cat
# 0  18.18125  80.5833  10.749882   985    0  very_cold     wet    gentle_breeze
# 1  17.68695  69.6087  16.652113   801    0  very_cold     wet  moderate_breeze
# 2   9.47025  43.7273  16.636703  1349    0  very_cold    good  moderate_breeze
# 3  10.60610  59.0435  10.739832  1562    0  very_cold     wet    gentle_breeze
# 4  11.46350  43.6957  12.522300  1600    0  very_cold    good    gentle_breeze

# %% [markdown]
# ### 2.5. Correlation between attributes

# %%
corr_matrix = df.corr()

# %%
sns.set(rc={'figure.figsize':(20,16)})
sns.heatmap(round(df.corr(), 2), annot=True)
# Out:
# <AxesSubplot:>

# %%
# finding high coorelation attributes
upper_matrix = corr_matrix.where(np.triu(np.ones(corr_matrix.shape),k=1).astype(bool))
to_drop = [column for column in upper_matrix.columns if any(np.abs(upper_matrix[column]) > 0.95)]
print("Drop columns:", to_drop)
df = df.drop(to_drop, axis=1)
# Out:
# Drop columns: ['atemp']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 717 entries, 0 to 729
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   season         717 non-null    int64
#  1   yr             717 non-null    int64
#  2   mnth           717 non-null    int64
#  3   holiday        717 non-null    int64
#  4   weekday        717 non-null    int64
#  5   workingday     717 non-null    int64
#  6   weathersit     717 non-null    int64
#  7   temp           717 non-null    float64
#  8   hum            717 non-null    float64
#  9   windspeed      717 non-null    float64
#  10  cnt            717 non-null    int64
#  11  day            717 non-null    int64
#  12  temp_cat       717 non-null    object
#  13  hum_cat        717 non-null    object
#  14  windspeed_cat  717 non-null    object
# dtypes: float64(3), int64(9), object(3)
# memory usage: 89.6+ KB

# %% [markdown]
# **Conclusion**: As we see, temp and atemp are high correlations, so we drop attemp to reduce dimensions of data

# %% [markdown]
# ### 2.6. EDA

# %% [markdown]
# #### 2.6.1 Univariate analysis

# %%
# temperature
sns.distplot(df["temp"])
# Out:
# <AxesSubplot:xlabel='temp', ylabel='Density'>

# %%
# humidity
sns.distplot(df["hum"])
# Out:
# <AxesSubplot:xlabel='hum', ylabel='Density'>

# %%
# windspeed
sns.distplot(df["windspeed"])
# Out:
# <AxesSubplot:xlabel='windspeed', ylabel='Density'>

# %%
# count
sns.distplot(df["cnt"])
# Out:
# <AxesSubplot:xlabel='cnt', ylabel='Density'>

# %% [markdown]
# #### 2.6.2 Bivariate analysis

# %% [markdown]
# ##### 2.6.2.1. Betweenn continous variable

# %%
plt.figure(figsize = (15,30))
sns.pairplot(data=df,vars=['cnt', 'temp', 'hum','windspeed'], kind='reg')
plt.show()

# %%
corr_matrix = df[['cnt', 'temp', 'hum','windspeed']].corr()
sns.set(rc={'figure.figsize':(20,16)})
sns.heatmap(round(corr_matrix, 2), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Finding**: from pairplot and coorelation heatmap we can see temp is higher correlation to windspeed and hum, respectively.

# %% [markdown]
# ##### 2.6.2.2. Betweenn categorical variable

# %%
# Converting season , day, and months's numerical values to categorical values
df.season.replace({1:"spring", 2:"summer", 3:"fall", 4:"winter"},inplace = True)

df.mnth = df.mnth.replace({1: 'jan',2: 'feb',3: 'mar',4: 'apr',5: 'may',6: 'jun',
                  7: 'jul',8: 'aug',9: 'sept',10: 'oct',11: 'nov',12: 'dec'})

df.weathersit.replace({1:'clear',2:'Mist',3:'Snow',4:'Heavy_Rain'},inplace = True)

df.weekday = df.weekday.replace({0: 'sun',1: 'mon',2: 'tue',3: 'wed',4: 'thu',5: 'fri',6: 'sat'})

df.day = df.day.replace({0:'start_month', 1:'mid_month', 2:'end_month'})

# %%
lst = ['season','yr','mnth','holiday','weekday','workingday', 'day','weathersit', 'temp_cat', 'hum_cat','windspeed_cat']

plt.figure(figsize=(25, 15))
for i, col_name in enumerate(lst):
    plt.subplot(4,5,i+1)
    if col_name == "windspeed_cat":
        sns.boxplot(data=df, x=col_name, y='cnt', order=wind_names)
    else:
        sns.boxplot(data=df, x=col_name, y='cnt')
plt.show()

# %% [markdown]
# **Finding**:
# Bike sharing bussiness:
# <ul>
#     <li>Demand by season, from high to low: 3 (Fall), 2 (Summer), 4 (Winter) and 1 (Fall), respectively.</li>
#     <li>Demand increase in 2019 compared to 2018</li>
#     <li>Demand in a year increase from January to September, then fall back.</li>
#     <li>Demand is higher when it is joliday</li>
#     <li>Weekends have slighty higher demand, but the mean is more or less the same. We can derive that there is not much impact of day of week in the data. And similar is with working day</li>
#     <li>End days of month have slightly decrease in number</bi>
#     <li>Weather impact much in demand: the worse weather is, the lower in demand.</li>
#     <li>People would like to have more demand on warm temperate day</li>
#     <li>Humidity not affected much for demand</li>
#     <li>The demand go highest in light air or light breeze day</li>
# </ul>

# %% [markdown]
# # Data prepatation
# Data provide with independent variables

# %% [markdown]
# ## 1 Create dummy variables

# %%
df = pd.get_dummies(data=df,columns=["season", "mnth", "day","weekday",
                                     "weathersit", 'temp_cat', 'hum_cat','windspeed_cat'],drop_first=True)

# %%
df.describe()
# Out:
#                yr     holiday  workingday        temp         hum   windspeed  \
# count  717.000000  717.000000  717.000000  717.000000  717.000000  717.000000
# mean     0.497908    0.029289    0.684798   20.394513   63.043984   12.488931
# std      0.500345    0.168732    0.464921    7.526460   14.105580    4.813331
# min      0.000000    0.000000    0.000000    2.424346    0.000000    1.500244
# 25%      0.000000    0.000000    0.000000   13.837500   52.458300    9.000043
# 50%      0.000000    0.000000    1.000000   20.739153   63.083300   11.959232
# 75%      1.000000    0.000000    1.000000   26.923347   73.250000   15.458575
# max      1.000000    1.000000    1.000000   35.328347   97.250000   25.333236
#
#                cnt  season_spring  season_summer  season_winter  ...  \
# count   717.000000     717.000000     717.000000     717.000000  ...
# mean   4531.154812       0.239888       0.252441       0.245467  ...
# std    1936.429965       0.427313       0.434716       0.430664  ...
# min      22.000000       0.000000       0.000000       0.000000  ...
# 25%    3214.000000       0.000000       0.000000       0.000000  ...
# 50%    4570.000000       0.000000       0.000000       0.000000  ...
# 75%    6031.000000       0.000000       1.000000       0.000000  ...
# max    8714.000000       1.000000       1.000000       1.000000  ...
#
#        temp_cat_very_cold  temp_cat_veryhot  temp_cat_warm  hum_cat_good  \
# count          717.000000        717.000000     717.000000    717.000000
# mean             0.301255          0.001395       0.237099      0.186890
# std              0.459124          0.037346       0.425600      0.390095
# min              0.000000          0.000000       0.000000      0.000000
# 25%              0.000000          0.000000       0.000000      0.000000
# 50%              0.000000          0.000000       0.000000      0.000000
# 75%              1.000000          0.000000       0.000000      0.000000
# max              1.000000          1.000000       1.000000      1.000000
#
#        hum_cat_wet  windspeed_cat_gentle_breeze  windspeed_cat_light_air  \
# count   717.000000                   717.000000               717.000000
# mean      0.807531                     0.412831                 0.016736
# std       0.394514                     0.492687                 0.128372
# min       0.000000                     0.000000                 0.000000
# 25%       1.000000                     0.000000                 0.000000
# 50%       1.000000                     0.000000                 0.000000
# 75%       1.000000                     1.000000                 0.000000
# max       1.000000                     1.000000                 1.000000
#
#        windspeed_cat_light_breeze  windspeed_cat_moderate_breeze  \
# count                  717.000000                     717.000000
# mean                     0.157601                       0.301255
# std                      0.364621                       0.459124
# min                      0.000000                       0.000000
# 25%                      0.000000                       0.000000
# 50%                      0.000000                       0.000000
# 75%                      0.000000                       1.000000
# max                      1.000000                       1.000000
#
#        windspeed_cat_strong_breeze
# count                   717.000000
# mean                      0.005579
# std                       0.074535
# min                       0.000000
# 25%                       0.000000
# 50%                       0.000000
# 75%                       0.000000
# max                       1.000000
#
# [8 rows x 43 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 717 entries, 0 to 729
# Data columns (total 43 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   yr                             717 non-null    int64
#  1   holiday                        717 non-null    int64
#  2   workingday                     717 non-null    int64
#  3   temp                           717 non-null    float64
#  4   hum                            717 non-null    float64
#  5   windspeed                      717 non-null    float64
#  6   cnt                            717 non-null    int64
#  7   season_spring                  717 non-null    uint8
#  8   season_summer                  717 non-null    uint8
#  9   season_winter                  717 non-null    uint8
#  10  mnth_aug                       717 non-null    uint8
#  11  mnth_dec                       717 non-null    uint8
#  12  mnth_feb                       717 non-null    uint8
#  13  mnth_jan                       717 non-null    uint8
#  14  mnth_jul                       717 non-null    uint8
#  15  mnth_jun                       717 non-null    uint8
#  16  mnth_mar                       717 non-null    uint8
#  17  mnth_may                       717 non-null    uint8
#  18  mnth_nov                       717 non-null    uint8
#  19  mnth_oct                       717 non-null    uint8
#  20  mnth_sept                      717 non-null    uint8
#  21  day_mid_month                  717 non-null    uint8
#  22  day_start_month                717 non-null    uint8
#  23  weekday_mon                    717 non-null    uint8
#  24  weekday_sat                    717 non-null    uint8
#  25  weekday_sun                    717 non-null    uint8
#  26  weekday_thu                    717 non-null    uint8
#  27  weekday_tue                    717 non-null    uint8
#  28  weekday_wed                    717 non-null    uint8
#  29  weathersit_Snow                717 non-null    uint8
#  30  weathersit_clear               717 non-null    uint8
#  31  temp_cat_hot                   717 non-null    uint8
#  32  temp_cat_normal                717 non-null    uint8
#  33  temp_cat_very_cold             717 non-null    uint8
#  34  temp_cat_veryhot               717 non-null    uint8
#  35  temp_cat_warm                  717 non-null    uint8
#  36  hum_cat_good                   717 non-null    uint8
#  37  hum_cat_wet                    717 non-null    uint8
#  38  windspeed_cat_gentle_breeze    717 non-null    uint8
#  39  windspeed_cat_light_air        717 non-null    uint8
#  40  windspeed_cat_light_breeze     717 non-null    uint8
#  41  windspeed_cat_moderate_breeze  717 non-null    uint8
#  42  windspeed_cat_strong_breeze    717 non-null    uint8
# dtypes: float64(3), int64(4), uint8(36)
# memory usage: 86.2 KB

# %% [markdown]
# ## 2 Devide data to train and test

# %%
#y to contain only target variable
y = df.pop('cnt')

#X is all remainign variable also our independent variables
X = df

#Train Test split with 80:20 ratio
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

# %%
print("X_train: ",X_train.shape)
print("y_train: ",y_train.shape)
print("X_test:  ",X_test.shape)
print("y_test:  ",y_test.shape)
# Out:
# X_train:  (573, 42)
# y_train:  (573,)
# X_test:   (144, 42)
# y_test:   (144,)

# %% [markdown]
# ## 3 Perform scaling
# "StandardScaler therefore cannot guarantee balanced feature scales in the presence of outliers." - sckitlearn website. So we choose MinMaxScaler

# %%
#Scale all the variable fron 0 to 1
scaler = MinMaxScaler()
num_vars = ['temp','hum','windspeed']
X_train[num_vars] = scaler.fit_transform(X_train[num_vars])
X_test[num_vars] = scaler.fit_transform(X_test[num_vars])

# %%
X_train.head()
# Out:
#      yr  holiday  workingday      temp       hum  windspeed  season_spring  \
# 666   1        0           1  0.474582  0.871230   0.944034              0
# 555   1        0           1  0.824514  0.575406   0.363619              0
# 724   1        0           1  0.229525  0.792343   0.826935              1
# 678   1        0           0  0.411242  0.544664   0.099670              0
# 527   1        0           1  0.740406  0.806264   0.540190              0
#
#      season_summer  season_winter  mnth_aug  ...  temp_cat_very_cold  \
# 666              0              1         0  ...                   0
# 555              0              0         0  ...                   0
# 724              0              0         0  ...                   1
# 678              0              1         0  ...                   0
# 527              1              0         0  ...                   0
#
#      temp_cat_veryhot  temp_cat_warm  hum_cat_good  hum_cat_wet  \
# 666                 0              0             0            1
# 555                 0              1             0            1
# 724                 0              0             0            1
# 678                 0              0             0            1
# 527                 0              1             0            1
#
#      windspeed_cat_gentle_breeze  windspeed_cat_light_air  \
# 666                            0                        0
# 555                            1                        0
# 724                            0                        0
# 678                            0                        1
# 527                            0                        0
#
#      windspeed_cat_light_breeze  windspeed_cat_moderate_breeze  \
# 666                           0                              0
# 555                           0                              0
# 724                           0                              0
# 678                           0                              0
# 527                           0                              1
#
#      windspeed_cat_strong_breeze
# 666                            0
# 555                            0
# 724                            0
# 678                            0
# 527                            0
#
# [5 rows x 42 columns]

# %%
X_train.describe()
# Out:
#                yr     holiday  workingday        temp         hum   windspeed  \
# count  573.000000  573.000000  573.000000  573.000000  573.000000  573.000000
# mean     0.502618    0.027923    0.694590    0.551739    0.528278    0.452801
# std      0.500430    0.164897    0.460983    0.229767    0.189304    0.201242
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.352054    0.390370    0.305955
# 50%      1.000000    0.000000    1.000000    0.561806    0.531322    0.426594
# 75%      1.000000    0.000000    1.000000    0.755981    0.662993    0.580424
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#        season_spring  season_summer  season_winter    mnth_aug  ...  \
# count     573.000000     573.000000     573.000000  573.000000  ...
# mean        0.221640       0.251309       0.254799    0.095986  ...
# std         0.415713       0.434145       0.436129    0.294829  ...
# min         0.000000       0.000000       0.000000    0.000000  ...
# 25%         0.000000       0.000000       0.000000    0.000000  ...
# 50%         0.000000       0.000000       0.000000    0.000000  ...
# 75%         0.000000       1.000000       1.000000    0.000000  ...
# max         1.000000       1.000000       1.000000    1.000000  ...
#
#        temp_cat_very_cold  temp_cat_veryhot  temp_cat_warm  hum_cat_good  \
# count          573.000000        573.000000     573.000000    573.000000
# mean             0.301920          0.001745       0.244328      0.178010
# std              0.459492          0.041776       0.430064      0.382856
# min              0.000000          0.000000       0.000000      0.000000
# 25%              0.000000          0.000000       0.000000      0.000000
# 50%              0.000000          0.000000       0.000000      0.000000
# 75%              1.000000          0.000000       0.000000      0.000000
# max              1.000000          1.000000       1.000000      1.000000
#
#        hum_cat_wet  windspeed_cat_gentle_breeze  windspeed_cat_light_air  \
# count   573.000000                   573.000000               573.000000
# mean      0.816754                     0.424084                 0.017452
# std       0.387206                     0.494635                 0.131063
# min       0.000000                     0.000000                 0.000000
# 25%       1.000000                     0.000000                 0.000000
# 50%       1.000000                     0.000000                 0.000000
# 75%       1.000000                     1.000000                 0.000000
# max       1.000000                     1.000000                 1.000000
#
#        windspeed_cat_light_breeze  windspeed_cat_moderate_breeze  \
# count                  573.000000                     573.000000
# mean                     0.169284                       0.286213
# std                      0.375331                       0.452385
# min                      0.000000                       0.000000
# 25%                      0.000000                       0.000000
# 50%                      0.000000                       0.000000
# 75%                      0.000000                       1.000000
# max                      1.000000                       1.000000
#
#        windspeed_cat_strong_breeze
# count                   573.000000
# mean                      0.005236
# std                       0.072231
# min                       0.000000
# 25%                       0.000000
# 50%                       0.000000
# 75%                       0.000000
# max                       1.000000
#
# [8 rows x 42 columns]

# %% [markdown]
# # DATA MODELLING AND EVALUATION

# %% [markdown]
# ### 1.1. Model with all attributes

# %%
model_1 = linear_regression(X_train, y_train, X_test, y_test)
# Out:
# R2 Score of the training data: 0.8795133283464509
# R2 Score of the testing data: 0.8441429466245672
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.880
# Model:                            OLS   Adj. R-squared:                  0.870
# Method:                 Least Squares   F-statistic:                     94.54
# Date:                Fri, 15 Apr 2022   Prob (F-statistic):          5.78e-216
# Time:                        01:16:25   Log-Likelihood:                -4532.3
# No. Observations:                 573   AIC:                             9149.
# Df Residuals:                     531   BIC:                             9331.
# Df Model:                          41
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                          1973.5591    601.346      3.282      0.001     792.251    3154.868
# yr                             1975.3313     60.060     32.889      0.000    1857.347    2093.316
# holiday                          55.7512    220.481      0.253      0.800    -377.370     488.873
# workingday                      723.6065    163.134      4.436      0.000     403.139    1044.074
# temp                           3023.9689    657.536      4.599      0.000    1732.277    4315.661
# hum                           -1963.6293    293.088     -6.700      0.000   -2539.384   -1387.875
# windspeed                     -1101.8288    500.489     -2.202      0.028   -2085.011    -118.647
# season_spring                 -1303.3280    230.338     -5.658      0.000   -1755.814    -850.842
# season_summer                  -237.6481    193.209     -1.230      0.219    -617.197     141.900
# season_winter                   350.0644    212.251      1.649      0.100     -66.890     767.019
# mnth_aug                       -150.2670    260.069     -0.578      0.564    -661.157     360.623
# mnth_dec                       -122.6926    261.631     -0.469      0.639    -636.652     391.267
# mnth_feb                        246.0965    257.774      0.955      0.340    -260.286     752.479
# mnth_jan                        126.1742    266.342      0.474      0.636    -397.040     649.388
# mnth_jul                       -156.2540    263.964     -0.592      0.554    -674.796     362.288
# mnth_jun                        -70.0541    193.983     -0.361      0.718    -451.123     311.015
# mnth_mar                        505.7692    192.645      2.625      0.009     127.330     884.209
# mnth_may                        127.9153    160.913      0.795      0.427    -188.189     444.019
# mnth_nov                       -233.9297    277.307     -0.844      0.399    -778.683     310.824
# mnth_oct                         98.2689    270.393      0.363      0.716    -432.903     629.441
# mnth_sept                       159.0984    244.215      0.651      0.515    -320.648     638.845
# day_mid_month                   167.0948     72.854      2.294      0.022      23.977     310.212
# day_start_month                 170.5337     72.180      2.363      0.019      28.740     312.328
# weekday_mon                    -255.4528    108.978     -2.344      0.019    -469.534     -41.371
# weekday_sat                     845.8297    163.756      5.165      0.000     524.141    1167.518
# weekday_sun                     348.3718    171.170      2.035      0.042      12.118     684.626
# weekday_thu                     -98.0608    108.401     -0.905      0.366    -311.009     114.887
# weekday_tue                    -105.9686    107.934     -0.982      0.327    -317.999     106.062
# weekday_wed                     -22.3661    107.762     -0.208      0.836    -234.058     189.325
# weathersit_Snow               -1247.3022    204.986     -6.085      0.000   -1649.985    -844.619
# weathersit_clear                459.9728     79.841      5.761      0.000     303.130     616.816
# temp_cat_hot                   -597.3990    298.418     -2.002      0.046   -1183.624     -11.174
# temp_cat_normal                 529.0419    147.216      3.594      0.000     239.846     818.238
# temp_cat_very_cold             -424.0284    137.780     -3.078      0.002    -694.689    -153.368
# temp_cat_veryhot              -2713.1855    781.612     -3.471      0.001   -4248.616   -1177.755
# temp_cat_warm                   314.5067    226.325      1.390      0.165    -130.095     759.109
# hum_cat_good                    466.6488    419.149      1.113      0.266    -356.746    1290.043
# hum_cat_wet                     897.8566    434.847      2.065      0.039      43.624    1752.089
# windspeed_cat_gentle_breeze    -118.7902    250.111     -0.475      0.635    -610.119     372.538
# windspeed_cat_light_air        -298.8599    453.743     -0.659      0.510   -1190.212     592.492
# windspeed_cat_light_breeze      -19.2231    335.620     -0.057      0.954    -678.529     640.083
# windspeed_cat_moderate_breeze    -6.0810    164.766     -0.037      0.971    -329.755     317.593
# windspeed_cat_strong_breeze   -1744.8160    424.169     -4.113      0.000   -2578.071    -911.561
# ==============================================================================
# Omnibus:                      101.639   Durbin-Watson:                   1.921
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              275.442
# Skew:                          -0.879   Prob(JB):                     1.54e-60
# Kurtosis:                       5.906   Cond. No.                     2.65e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.89e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# After getting the intial results we see that although our R2 and adj.R2 is 88% and 87%, our F statistic is low and also we see that the p value for lot of our variables is very high. we also see a problem of multi-collinearity.

# %% [markdown]
# ### 1.2. Model using RFE variables

# %%
# # Linear Regression model with all attributes
model_1 = LinearRegression()
model_1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Using RFE to rank 15 columns
rfe = RFE(model_1, n_features_to_select=20, step=1, verbose=0, importance_getter='auto')
rfe.fit(X_train,y_train)
list(zip(X_train.columns, rfe.support_, rfe.ranking_))
# Out:
# [('yr', True, 1),
#  ('holiday', True, 1),
#  ('workingday', True, 1),
#  ('temp', True, 1),
#  ('hum', True, 1),
#  ('windspeed', True, 1),
#  ('season_spring', True, 1),
#  ('season_summer', False, 13),
#  ('season_winter', True, 1),
#  ('mnth_aug', False, 16),
#  ('mnth_dec', False, 15),
#  ('mnth_feb', False, 6),
#  ('mnth_jan', False, 8),
#  ('mnth_jul', False, 17),
#  ('mnth_jun', False, 20),
#  ('mnth_mar', True, 1),
#  ('mnth_may', False, 12),
#  ('mnth_nov', False, 11),
#  ('mnth_oct', False, 3),
#  ('mnth_sept', True, 1),
#  ('day_mid_month', False, 10),
#  ('day_start_month', False, 9),
#  ('weekday_mon', False, 5),
#  ('weekday_sat', True, 1),
#  ('weekday_sun', True, 1),
#  ('weekday_thu', False, 19),
#  ('weekday_tue', False, 18),
#  ('weekday_wed', False, 21),
#  ('weathersit_Snow', True, 1),
#  ('weathersit_clear', True, 1),
#  ('temp_cat_hot', True, 1),
#  ('temp_cat_normal', True, 1),
#  ('temp_cat_very_cold', False, 2),
#  ('temp_cat_veryhot', True, 1),
#  ('temp_cat_warm', False, 4),
#  ('hum_cat_good', True, 1),
#  ('hum_cat_wet', True, 1),
#  ('windspeed_cat_gentle_breeze', False, 14),
#  ('windspeed_cat_light_air', False, 7),
#  ('windspeed_cat_light_breeze', False, 22),
#  ('windspeed_cat_moderate_breeze', False, 23),
#  ('windspeed_cat_strong_breeze', True, 1)]

# %%
X_train_RFE = X_train[X_train.columns[rfe.support_]]
X_test_RFE  = X_test[X_test.columns[rfe.support_]]
model_2     = linear_regression(X_train_RFE, y_train, X_test_RFE, y_test)
# Out:
# R2 Score of the training data: 0.8708355893143576
# R2 Score of the testing data: 0.8467794384993085
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.871
# Model:                            OLS   Adj. R-squared:                  0.866
# Method:                 Least Squares   F-statistic:                     196.2
# Date:                Fri, 15 Apr 2022   Prob (F-statistic):          2.90e-231
# Time:                        01:16:26   Log-Likelihood:                -4552.2
# No. Observations:                 573   AIC:                             9144.
# Df Residuals:                     553   BIC:                             9231.
# Df Model:                          19
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                        1153.5045    355.251      3.247      0.001     455.699    1851.310
# yr                           1958.4613     59.655     32.830      0.000    1841.282    2075.640
# holiday                      -340.5106    170.146     -2.001      0.046    -674.723      -6.299
# workingday                    519.2339    102.361      5.073      0.000     318.170     720.298
# temp                         4498.2006    238.786     18.838      0.000    4029.162    4967.239
# hum                         -1879.1160    280.760     -6.693      0.000   -2430.602   -1327.630
# windspeed                    -996.4184    160.958     -6.191      0.000   -1312.583    -680.254
# season_spring                -941.4123    116.715     -8.066      0.000   -1170.671    -712.153
# season_winter                 467.0285     91.783      5.088      0.000     286.742     647.315
# mnth_mar                      372.2971    120.171      3.098      0.002     136.249     608.345
# mnth_sept                     323.9901    116.940      2.771      0.006      94.289     553.691
# weekday_sat                   746.9871    112.691      6.629      0.000     525.632     968.342
# weekday_sun                   227.7941    113.228      2.012      0.045       5.384     450.204
# weathersit_Snow             -1266.7602    203.151     -6.236      0.000   -1665.802    -867.718
# weathersit_clear              429.5469     79.079      5.432      0.000     274.214     584.879
# temp_cat_hot                -1087.5252    119.897     -9.071      0.000   -1323.034    -852.017
# temp_cat_normal               472.5784     82.448      5.732      0.000     310.628     634.529
# temp_cat_veryhot            -3374.6610    709.868     -4.754      0.000   -4769.028   -1980.294
# hum_cat_good                  445.7528    418.439      1.065      0.287    -376.172    1267.677
# hum_cat_wet                   809.6780    431.841      1.875      0.061     -38.571    1657.927
# windspeed_cat_strong_breeze -1851.5554    414.911     -4.463      0.000   -2666.549   -1036.562
# ==============================================================================
# Omnibus:                       93.895   Durbin-Watson:                   1.899
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              257.766
# Skew:                          -0.810   Prob(JB):                     1.06e-56
# Kurtosis:                       5.859   Cond. No.                     2.32e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.15e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# After creating our 2nd model using RFE feature selection technique we see that our adj.R2 have increased compared to our 1st model and our F-statictic has also significantly increased suggesting a better fit. Also, RFE took care of the multi collinearity problem for us and we do not see high P-values for any of the variable

# %% [markdown]
# ### 1.3 Feature Selection Using VIF and P-Values

# %%
cols = list(X_train.columns[rfe.support_])
X_train_RFE = X_train[cols]
X_test_RFE  = X_test[cols]
model_3 = linear_regression(X_train[cols], y_train, X_test[cols], y_test, print_chart=False)
print(get_VIF(X_train[cols]))
# Out:
# R2 Score of the training data: 0.8708355893143576
# R2 Score of the testing data: 0.8467794384993085
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.871
# Model:                            OLS   Adj. R-squared:                  0.866
# Method:                 Least Squares   F-statistic:                     196.2
# Date:                Fri, 15 Apr 2022   Prob (F-statistic):          2.90e-231
# Time:                        01:16:26   Log-Likelihood:                -4552.2
# No. Observations:                 573   AIC:                             9144.
# Df Residuals:                     553   BIC:                             9231.
# Df Model:                          19
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                        1153.5045    355.251      3.247      0.001     455.699    1851.310
# yr                           1958.4613     59.655     32.830      0.000    1841.282    2075.640
# holiday                      -340.5106    170.146     -2.001      0.046    -674.723      -6.299
# workingday                    519.2339    102.361      5.073      0.000     318.170     720.298
# temp                         4498.2006    238.786     18.838      0.000    4029.162    4967.239
# hum                         -1879.1160    280.760     -6.693      0.000   -2430.602   -1327.630
# windspeed                    -996.4184    160.958     -6.191      0.000   -1312.583    -680.254
# season_spring                -941.4123    116.715     -8.066      0.000   -1170.671    -712.153
# season_winter                 467.0285     91.783      5.088      0.000     286.742     647.315
# mnth_mar                      372.2971    120.171      3.098      0.002     136.249     608.345
# mnth_sept                     323.9901    116.940      2.771      0.006      94.289     553.691
# weekday_sat                   746.9871    112.691      6.629      0.000     525.632     968.342
# weekday_sun                   227.7941    113.228      2.012      0.045       5.384     450.204
# weathersit_Snow             -1266.7602    203.151     -6.236      0.000   -1665.802    -867.718
# weathersit_clear              429.5469     79.079      5.432      0.000     274.214     584.879
# temp_cat_hot                -1087.5252    119.897     -9.071      0.000   -1323.034    -852.017
# temp_cat_normal               472.5784     82.448      5.732      0.000     310.628     634.529
# temp_cat_veryhot            -3374.6610    709.868     -4.754      0.000   -4769.028   -1980.294
# hum_cat_good                  445.7528    418.439      1.065      0.287    -376.172    1267.677
# hum_cat_wet                   809.6780    431.841      1.875      0.061     -38.571    1657.927
# windspeed_cat_strong_breeze -1851.5554    414.911     -4.463      0.000   -2666.549   -1036.562
# ==============================================================================
# Omnibus:                       93.895   Durbin-Watson:                   1.899
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              257.766
# Skew:                          -0.810   Prob(JB):                     1.06e-56
# Kurtosis:                       5.859   Cond. No.                     2.32e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.15e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                         feature         VIF
# 2                    workingday  162.155906
# 18                  hum_cat_wet   33.146839
# 10                  weekday_sat   32.720846
# 11                  weekday_sun   32.465783
# 17                 hum_cat_good   30.426042
# 1                       holiday    7.625908
# 3                          temp    3.568653
# 4                           hum    3.348872
# 6                 season_spring    2.790950
# 7                 season_winter    1.899629
# 13             weathersit_clear    1.717279
# 14                 temp_cat_hot    1.576846
# 12              weathersit_Snow    1.249464
# 5                     windspeed    1.243861
# 15              temp_cat_normal    1.125934
# 8                      mnth_mar    1.113648
# 9                     mnth_sept    1.103141
# 19  windspeed_cat_strong_breeze    1.064792
# 0                            yr    1.056568
# 16             temp_cat_veryhot    1.042583

# %%
cols.remove('hum_cat_good')
model_3 = linear_regression(X_train[cols], y_train, X_test[cols], y_test, print_chart=False)
print(get_VIF(X_train[cols]))
# Out:
# R2 Score of the training data: 0.8705705311016743
# R2 Score of the testing data: 0.846440060016608
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.871
# Model:                            OLS   Adj. R-squared:                  0.866
# Method:                 Least Squares   F-statistic:                     207.0
# Date:                Fri, 15 Apr 2022   Prob (F-statistic):          3.50e-232
# Time:                        01:16:26   Log-Likelihood:                -4552.8
# No. Observations:                 573   AIC:                             9144.
# Df Residuals:                     554   BIC:                             9226.
# Df Model:                          18
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                        1474.8670    187.633      7.860      0.000    1106.307    1843.427
# yr                           1955.1053     59.579     32.815      0.000    1838.076    2072.135
# holiday                      -259.2208    152.093     -1.704      0.089    -557.971      39.529
# workingday                    601.9435     66.713      9.023      0.000     470.902     732.985
# temp                         4517.3668    238.136     18.970      0.000    4049.607    4985.127
# hum                         -1835.3143    277.766     -6.607      0.000   -2380.918   -1289.711
# windspeed                    -994.3981    160.967     -6.178      0.000   -1310.578    -678.219
# season_spring                -924.5694    115.653     -7.994      0.000   -1151.742    -697.397
# season_winter                 475.0102     91.488      5.192      0.000     295.304     654.716
# mnth_mar                      361.5720    119.763      3.019      0.003     126.326     596.818
# mnth_sept                     322.3609    116.944      2.757      0.006      92.652     552.070
# weekday_sat                   827.2023     83.850      9.865      0.000     662.499     991.906
# weekday_sun                   304.9420     87.050      3.503      0.000     133.953     475.931
# weathersit_Snow             -1277.1581    202.941     -6.293      0.000   -1675.786    -878.530
# weathersit_clear              434.2842     78.964      5.500      0.000     279.179     589.389
# temp_cat_hot                -1085.7167    119.899     -9.055      0.000   -1321.229    -850.204
# temp_cat_normal               470.3848     82.433      5.706      0.000     308.466     632.304
# temp_cat_veryhot            -3366.3425    709.911     -4.742      0.000   -4760.789   -1971.896
# hum_cat_wet                   364.0040    107.050      3.400      0.001     153.730     574.278
# windspeed_cat_strong_breeze -1848.1899    414.949     -4.454      0.000   -2663.256   -1033.124
# ==============================================================================
# Omnibus:                       94.308   Durbin-Watson:                   1.885
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              256.892
# Skew:                          -0.816   Prob(JB):                     1.65e-56
# Kurtosis:                       5.846   Cond. No.                     2.32e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.15e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                         feature        VIF
# 2                    workingday  43.472043
# 11                  weekday_sun   9.551978
# 10                  weekday_sat   9.158419
# 3                          temp   3.548393
# 4                           hum   3.277045
# 1                       holiday   2.888166
# 6                 season_spring   2.739734
# 17                  hum_cat_wet   2.036409
# 7                 season_winter   1.886969
# 13             weathersit_clear   1.711849
# 14                 temp_cat_hot   1.576530
# 12              weathersit_Snow   1.246579
# 5                     windspeed   1.243689
# 15              temp_cat_normal   1.125232
# 8                      mnth_mar   1.105831
# 9                     mnth_sept   1.102952
# 18  windspeed_cat_strong_breeze   1.064730
# 0                            yr   1.053622
# 16             temp_cat_veryhot   1.042457

# %%
cols.remove('workingday')
model_3 = linear_regression(X_train[cols], y_train, X_test[cols], y_test, print_chart=False)
print(get_VIF(X_train[cols]))
# Out:
# R2 Score of the training data: 0.8705705311016743
# R2 Score of the testing data: 0.8464400600166102
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.871
# Model:                            OLS   Adj. R-squared:                  0.866
# Method:                 Least Squares   F-statistic:                     207.0
# Date:                Fri, 15 Apr 2022   Prob (F-statistic):          3.50e-232
# Time:                        01:16:26   Log-Likelihood:                -4552.8
# No. Observations:                 573   AIC:                             9144.
# Df Residuals:                     554   BIC:                             9226.
# Df Model:                          18
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                        2076.8104    229.593      9.046      0.000    1625.831    2527.790
# yr                           1955.1053     59.579     32.815      0.000    1838.076    2072.135
# holiday                      -861.1642    178.696     -4.819      0.000   -1212.168    -510.161
# temp                         4517.3668    238.136     18.970      0.000    4049.607    4985.127
# hum                         -1835.3143    277.766     -6.607      0.000   -2380.918   -1289.711
# windspeed                    -994.3981    160.967     -6.178      0.000   -1310.578    -678.219
# season_spring                -924.5694    115.653     -7.994      0.000   -1151.742    -697.397
# season_winter                 475.0102     91.488      5.192      0.000     295.304     654.716
# mnth_mar                      361.5720    119.763      3.019      0.003     126.326     596.818
# mnth_sept                     322.3609    116.944      2.757      0.006      92.652     552.070
# weekday_sat                   225.2589     86.651      2.600      0.010      55.055     395.463
# weekday_sun                  -297.0015     86.588     -3.430      0.001    -467.083    -126.920
# weathersit_Snow             -1277.1581    202.941     -6.293      0.000   -1675.786    -878.530
# weathersit_clear              434.2842     78.964      5.500      0.000     279.179     589.389
# temp_cat_hot                -1085.7167    119.899     -9.055      0.000   -1321.229    -850.204
# temp_cat_normal               470.3848     82.433      5.706      0.000     308.466     632.304
# temp_cat_veryhot            -3366.3425    709.911     -4.742      0.000   -4760.789   -1971.896
# hum_cat_wet                   364.0040    107.050      3.400      0.001     153.730     574.278
# windspeed_cat_strong_breeze -1848.1899    414.949     -4.454      0.000   -2663.256   -1033.124
# ==============================================================================
# Omnibus:                       94.308   Durbin-Watson:                   1.885
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              256.892
# Skew:                          -0.816   Prob(JB):                     1.65e-56
# Kurtosis:                       5.846   Cond. No.                         45.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                         feature        VIF
# 3                           hum  21.663649
# 2                          temp  17.403510
# 16                  hum_cat_wet  11.055359
# 4                     windspeed   5.443992
# 12             weathersit_clear   3.753717
# 5                 season_spring   2.546555
# 6                 season_winter   2.063539
# 0                            yr   2.027750
# 13                 temp_cat_hot   1.735219
# 14              temp_cat_normal   1.351691
# 11              weathersit_Snow   1.247577
# 9                   weekday_sat   1.225200
# 10                  weekday_sun   1.224630
# 7                      mnth_mar   1.187831
# 8                     mnth_sept   1.184598
# 17  windspeed_cat_strong_breeze   1.059510
# 1                       holiday   1.057700
# 15             temp_cat_veryhot   1.041882

# %%
cols.remove('hum')
model_3 = linear_regression(X_train[cols], y_train, X_test[cols], y_test, print_chart=False)
print(get_VIF(X_train[cols]))
# Out:
# R2 Score of the training data: 0.8603708715226647
# R2 Score of the testing data: 0.8630237078766203
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.860
# Model:                            OLS   Adj. R-squared:                  0.856
# Method:                 Least Squares   F-statistic:                     201.2
# Date:                Fri, 15 Apr 2022   Prob (F-statistic):          2.95e-224
# Time:                        01:16:26   Log-Likelihood:                -4574.5
# No. Observations:                 573   AIC:                             9185.
# Df Residuals:                     555   BIC:                             9263.
# Df Model:                          17
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                        1319.9892    206.486      6.393      0.000     914.399    1725.579
# yr                           2026.8856     60.790     33.342      0.000    1907.478    2146.293
# holiday                      -898.4660    185.343     -4.848      0.000   -1262.526    -534.406
# temp                         4279.7624    244.285     17.520      0.000    3799.927    4759.598
# windspeed                    -789.8004    163.918     -4.818      0.000   -1111.776    -467.824
# season_spring                -940.3661    119.990     -7.837      0.000   -1176.056    -704.676
# season_winter                 426.3445     94.631      4.505      0.000     240.466     612.223
# mnth_mar                      310.3616    124.020      2.503      0.013      66.755     553.968
# mnth_sept                     253.1686    120.868      2.095      0.037      15.754     490.583
# weekday_sat                   253.5443     89.809      2.823      0.005      77.136     429.952
# weekday_sun                  -362.4325     89.265     -4.060      0.000    -537.771    -187.094
# weathersit_Snow             -1722.1827    198.660     -8.669      0.000   -2112.399   -1331.966
# weathersit_clear              716.0671     68.964     10.383      0.000     580.605     851.529
# temp_cat_hot                 -979.1818    123.292     -7.942      0.000   -1221.357    -737.007
# temp_cat_normal               453.3864     85.500      5.303      0.000     285.443     621.330
# temp_cat_veryhot            -3442.8245    736.591     -4.674      0.000   -4889.671   -1995.978
# hum_cat_wet                   -70.4123     87.668     -0.803      0.422    -242.614     101.789
# windspeed_cat_strong_breeze -1985.8898    430.057     -4.618      0.000   -2830.628   -1141.151
# ==============================================================================
# Omnibus:                       97.640   Durbin-Watson:                   1.844
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              279.553
# Skew:                          -0.827   Prob(JB):                     1.98e-61
# Kurtosis:                       5.995   Cond. No.                         43.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                         feature        VIF
# 2                          temp  11.937810
# 15                  hum_cat_wet   6.108253
# 3                     windspeed   5.393075
# 11             weathersit_clear   3.131768
# 4                 season_spring   2.171202
# 0                            yr   2.010071
# 5                 season_winter   1.769910
# 12                 temp_cat_hot   1.650180
# 13              temp_cat_normal   1.350012
# 8                   weekday_sat   1.224922
# 9                   weekday_sun   1.193655
# 7                     mnth_sept   1.179744
# 6                      mnth_mar   1.177926
# 10              weathersit_Snow   1.139028
# 16  windspeed_cat_strong_breeze   1.059510
# 1                       holiday   1.057313
# 14             temp_cat_veryhot   1.041802

# %%
cols.remove('hum_cat_wet')
model_3 = linear_regression(X_train[cols], y_train, X_test[cols], y_test, print_chart=False)
print(get_VIF(X_train[cols]))
# Out:
# R2 Score of the training data: 0.8602085791415035
# R2 Score of the testing data: 0.8616660362005591
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.860
# Model:                            OLS   Adj. R-squared:                  0.856
# Method:                 Least Squares   F-statistic:                     213.8
# Date:                Fri, 15 Apr 2022   Prob (F-statistic):          2.73e-225
# Time:                        01:16:26   Log-Likelihood:                -4574.9
# No. Observations:                 573   AIC:                             9184.
# Df Residuals:                     556   BIC:                             9258.
# Df Model:                          16
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                        1263.1531    193.920      6.514      0.000     882.248    1644.058
# yr                           2028.0599     60.753     33.382      0.000    1908.726    2147.394
# holiday                      -904.2133    185.146     -4.884      0.000   -1267.884    -540.542
# temp                         4242.2042    239.691     17.699      0.000    3771.394    4713.014
# windspeed                    -763.1681    160.478     -4.756      0.000   -1078.386    -447.950
# season_spring                -947.2280    119.647     -7.917      0.000   -1182.244    -712.212
# season_winter                 414.6557     93.475      4.436      0.000     231.048     598.264
# mnth_mar                      313.3572    123.925      2.529      0.012      69.940     556.775
# mnth_sept                     249.2223    120.729      2.064      0.039      12.081     486.364
# weekday_sat                   256.7338     89.693      2.862      0.004      80.555     432.912
# weekday_sun                  -360.1446     89.191     -4.038      0.000    -535.337    -184.952
# weathersit_Snow             -1731.3688    198.267     -8.733      0.000   -2120.812   -1341.925
# weathersit_clear              733.0715     65.613     11.173      0.000     604.193     861.950
# temp_cat_hot                 -971.5915    122.890     -7.906      0.000   -1212.976    -730.207
# temp_cat_normal               453.0273     85.472      5.300      0.000     285.140     620.914
# temp_cat_veryhot            -3380.3673    732.240     -4.616      0.000   -4818.663   -1942.072
# windspeed_cat_strong_breeze -1994.1371    429.797     -4.640      0.000   -2838.362   -1149.912
# ==============================================================================
# Omnibus:                       96.856   Durbin-Watson:                   1.847
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              274.025
# Skew:                          -0.824   Prob(JB):                     3.14e-60
# Kurtosis:                       5.959   Cond. No.                         38.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                         feature       VIF
# 2                          temp  6.973890
# 3                     windspeed  5.386569
# 11             weathersit_clear  2.946294
# 0                            yr  2.008894
# 4                 season_spring  1.851318
# 12                 temp_cat_hot  1.607148
# 5                 season_winter  1.439627
# 13              temp_cat_normal  1.349831
# 8                   weekday_sat  1.224894
# 9                   weekday_sun  1.193533
# 7                     mnth_sept  1.178444
# 6                      mnth_mar  1.177880
# 10              weathersit_Snow  1.134355
# 15  windspeed_cat_strong_breeze  1.059467
# 1                       holiday  1.056013
# 14             temp_cat_veryhot  1.024395

# %% [markdown]
# ### 1.4. Final model

# %%
model_final = LinearRegression()
model_final.fit(X_train[cols], y_train)
print("Intercept:", model_final.intercept_)
print("Coef     :\n", model_final.coef_)
# Out:
# Intercept: 1263.1531333413031
# Coef     :
#  [ 2028.05993347  -904.21330856  4242.20420846  -763.16806367
#   -947.22801552   414.65574986   313.35717344   249.22230896
#    256.73383804  -360.14461387 -1731.36882266   733.07149735
#   -971.59149341   453.02726861 -3380.36733201 -1994.1370665 ]

# %% [markdown]
# ## 2. MODEL EVALUATION

# %% [markdown]
# ### 2.1. Residual analysis

# %%
y_train_pred = model_final.predict(X_train[cols])
sns.distplot(y_train-y_train_pred)
plt.title('Error Terms')
plt.xlabel('Errors')
# Out:
# Text(0.5, 0, 'Errors')

# %% [markdown]
# Error terms are normally distributed with mean at 0.

# %% [markdown]
# #### 2.1.2. Homoscedasticity check

# %%
residual = (y_train - y_train_pred)
plt.scatter(y_train_pred,residual)
plt.ylabel("error")
plt.xlabel("y_train")
plt.title('Homoscedasticity Check')
plt.show()

# %%
# method for cheking LR assumptions
def assumptions(model, X_train, X_test, y_train, y_test):
  # 0. checking R2 score on test and training set
  r2_test = r2_score(y_test,model.predict(sm.add_constant(X_test)))
  r2_train = r2_score(y_train,model.predict(sm.add_constant(X_train)))
  print("R2 for training set:",r2_train,"\nR2 for test set:",r2_test)
  # 1. checking if the residual mean is 0
  y_pred = model.predict(sm.add_constant(X_train))
  residuals = y_train.values - y_pred
  print("Residual Mean Error is:",round(residuals.mean(),3))
  # 2. check for homoscedasticity
  fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(28,6))
  sns.scatterplot(y_pred,residuals, ax=ax1)
  ax1.set_xlabel("Residuals")
  ax1.set_ylabel("Predictions")
  ax1.set_title("Homoscedasticity Check")
  sns.lineplot([0,8000],[0,0],color='red', ax=ax1)
  # 3. check for normality of error terms/residuals
  sns.distplot(residuals, ax=ax2)
  ax2.set_xlabel("Residuals")
  ax2.set_title("Normality of Error Terms Check")
  # 4. check for multi collinearity
  cmap = sns.diverging_palette(230, 20, as_cmap=True)
  sns.heatmap(X_train.corr(), cmap=cmap, ax=ax3)
  ax3.set_title("Multi-Collinearity Check")

# %%
assumptions(model_2,X_train_RFE, X_test_RFE,y_train,y_test)
# Out:
# R2 for training set: 0.8708355893143576
# R2 for test set: 0.8467794384993085
# Residual Mean Error is: 0.0

# %%
assumptions(model_3,X_train[cols], X_test[cols],y_train,y_test)
# Out:
# R2 for training set: 0.8602085791415035
# R2 for test set: 0.8616660362005591
# Residual Mean Error is: -0.0
